# %%
numbers = sc.parallelize(range(10))

# %%
numbers.takeSample(withReplacement=False, num=1,seed=1)
# Out:
# [6]

# %%
numbers.takeSample(withReplacement=False, num=1,seed=2)
# Out:
# [5]

# %%
numbers.takeSample(withReplacement=False, num=10000,seed=2)
# Out:
# [5, 9, 3, 4, 6, 7, 2, 8, 1, 0]

# %%
len(numbers.takeSample(withReplacement=True, num=10000,seed=2))
# Out:
# 10000
