# %%
numbers = sc.parallelize(range(1000000000),numSlices=10)

# %%
numbers.count()
# Out:
# 1000000000

# %%
numbers.countApprox(timeout=200,confidence=0.5)
# Out:
# [Stage 4:>                                                        (0 + 10) / 10]
# 1000000000

# %%
numbers.countApproxDistinct()
# Out:
# 1003690428

# %%
numbers.countApproxDistinct(relativeSD=0.04)
# Out:
# 992718825
