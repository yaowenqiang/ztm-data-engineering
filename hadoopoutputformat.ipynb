# %% [markdown]
# Old API - org.apache.hadoop.mapred
#
# saveAsHadoopDataset
#
# saveAsHadoopFile

# %% [markdown]
# New API - org.apache.hadoop.mapreduce
#
# saveAsNewAPIHadoopDataset
#
# saveAsNewAPIHadoopFile

# %% [markdown]
# rdd.SaveAsHadoopDataset(confg,keyConveter,valueConverter)

# %%
rdd.saveAsHadoopFile(
    path='output-file',
    outputFormatClass = 'org.apache.hadoop.mapred.TextOutputFormat',
    keyclass=None,
    valueClass=None,
    keyConverter=None,
    valueConverter=None,
    conf=None,
    compressionCodecClass='org.apache.hadoop.io.compress.GzipCodec',
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 rdd.saveAsHadoopFile(
#       2     path='output-file',
#       3     outputFormatClass = 'org.apache.hadoop.mapred.TextOutputFormat',
#       4     keyclass=None,
#       5     valueClass=None,
#       6     keyConverter=None,
#       7     valueConverter=None,
#       8     conf=None,
#       9     compressionCodecClass='org.apache.hadoop.io.compress.GzipCodec',
#      10 )
#
# NameError: name 'rdd' is not defined
