# %%
input = sc.parallelize(range(10000))

# %%
result = input.map(lambda x: x ** 5)

# %%
result.saveAsTextFile('first-output.txt')

# %%
result.map(lambda x: 'number:' + str(x)).saveAsTextFile('second-output.txt')

# %%
result
# Out:
# PythonRDD[4] at RDD at PythonRDD.scala:58

# %%
result.persist()

# %%
from pyspark import StorageLevel

# %%
input.persist(StorageLevel.MEMORY_ONLY)
# Out:
# PythonRDD[3] at RDD at PythonRDD.scala:58

# %%
input.is_cached
# Out:
# True

# %%
input.unpersist()
# Out:
# PythonRDD[3] at RDD at PythonRDD.scala:58

# %%
input.is_cached
# Out:
# False
