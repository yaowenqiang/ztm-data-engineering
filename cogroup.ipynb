# %%
a = sc.parallelize([(1,'a'),(2,'a')])

# %%
b = sc.parallelize([(2,'b'),(2,'c'),(3,'d')])

# %%
a.join(b).collect()
# Out:
# [(2, ('a', 'b')), (2, ('a', 'c'))]

# %%
a.cogroup(b).collect()
# Out:
# [(1,
#   (<pyspark.resultiterable.ResultIterable at 0x1136f8b50>,
#    <pyspark.resultiterable.ResultIterable at 0x113dbab50>)),
#  (2,
#   (<pyspark.resultiterable.ResultIterable at 0x113e3c2d0>,
#    <pyspark.resultiterable.ResultIterable at 0x112f272d0>)),
#  (3,
#   (<pyspark.resultiterable.ResultIterable at 0x111816350>,
#    <pyspark.resultiterable.ResultIterable at 0x112f24f90>))]

# %%
a.cogroup(b).mapValues(lambda x:[list(x[0]),list(x[1])]).collect()
# Out:
# [(1, [['a'], []]), (2, [['a'], ['b', 'c']]), (3, [[], ['d']])]
