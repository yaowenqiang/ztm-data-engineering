# %%
numbers = sc.parallelize(range(10))

# %%
numbers.first()
# Out:
# 0

# %%
sc.parallelize([3,2,1]).sortBy(lambda x: x).first()
# Out:
# 1

# %%
sc.parallelize([]).first()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 sc.parallelize([]).first()
#
# File /opt/homebrew/Cellar/apache-spark/4.1.1/libexec/python/pyspark/core/rdd.py:2758, in RDD.first(self)
#    2756 if rs:
#    2757     return rs[0]
# -> 2758 raise ValueError("RDD is empty")
#
# ValueError: RDD is empty
