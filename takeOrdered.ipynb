# %%
numbers = sc.parallelize([1,2,3,6,7,8,4,5,1])

# %%
numbers.take(10)
# Out:
# [1, 2, 3, 6, 7, 8, 4, 5, 1]

# %%
numbers.takeOrdered(10)
# Out:
# [1, 1, 2, 3, 4, 5, 6, 7, 8]

# %%
numbers.takeOrdered(10,key=lambda x:-x)
# Out:
# [8, 7, 6, 5, 4, 3, 2, 1, 1]
