# %%
text = sc.textFile('file_name.txt')

# %%
text
# Out:
# file_name.txt MapPartitionsRDD[1] at textFile at NativeMethodAccessorImpl.java:0

# %%
text.collect()

# %%
text = sc.textFile('file.txt', minPartitions=20)

# %%
text = sc.textFile('file.txt', minPartitions=20,use_unicode=True)
