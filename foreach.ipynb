# %%
def add_to_queue(x, queue=[]):
    queue += [x]
    return queue

# %%
add_to_queue(3)
# Out:
# [3]

# %%
add_to_queue(4)
# Out:
# [3, 4]

# %%
add_to_queue(5)
# Out:
# [3, 4, 5]

# %%
numbers = sc.parallelize(range(100))

# %%
numbers.foreach(add_to_queue)

# %%
add_to_queue(5)
# Out:
# [3, 4, 5, 5]
