# %%
numbers = sc.parallelize(range(10000), numSlices=5)

# %%
numbers.saveAsTextFile('our_test_numbers')

# %%
numbers.saveAsTextFile('out_test_numbers.gz', compressionCodecClass='org.apache.hadoop.io.compress.GzipCodec')
